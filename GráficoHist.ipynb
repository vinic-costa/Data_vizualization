# %% [markdown]
# ## **Visualização de dados - Histograma**
#
# ---

# %% [markdown]
# > **RELEMBRANDO A SITUAÇÃO PROBLEMA**
#
# Vamos supor que você seja dono de um banco em Taiwan que oferta serviço de crédito. Você tem em mãos uma tabela em excel com dados dos clientes que contrataram o serviço de crédito.
#
# `Objetivo`: apresentar um panorama consolidado sobre a situação dos clientes no banco para o restante da empresa.
#
# `Objetivo específico`: analisar a distribuição da frequência de idade de acordo com o sexo.

# %%
# Importando as bibliotecas

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Lendo dados tabulares

credit = pd.read_excel("/content/clientes_renamed.xlsx")

# %%
credit
# Out:
#        Unnamed: 0     ID  valor_credito  sexo  nivel_escolaridade  \
# 0               0      1          20000     2                   2
# 1               1      2         120000     2                   2
# 2               2      3          90000     2                   2
# 3               3      4          50000     2                   2
# 4               4      5          50000     1                   2
# ...           ...    ...            ...   ...                 ...
# 29927       29995  29996         220000     1                   3
# 29928       29996  29997         150000     1                   3
# 29929       29997  29998          30000     1                   2
# 29930       29998  29999          80000     1                   3
# 29931       29999  30000          50000     1                   2
#
#        estado_civil  idade  status_pag_set_2005  status_pag_ago_2005  \
# 0                 1     24                    2                    2
# 1                 2     26                   -1                    2
# 2                 2     34                    0                    0
# 3                 1     37                    0                    0
# 4                 1     57                   -1                    0
# ...             ...    ...                  ...                  ...
# 29927             1     39                    0                    0
# 29928             2     43                   -1                   -1
# 29929             2     37                    4                    3
# 29930             1     41                    1                   -1
# 29931             1     46                    0                    0
#
#        status_pag_jul_2005  ...  extrato_jul_2005  extrato_jun_2005  \
# 0                       -1  ...               689                 0
# 1                        0  ...              2682              3272
# 2                        0  ...             13559             14331
# 3                        0  ...             49291             28314
# 4                       -1  ...             35835             20940
# ...                    ...  ...               ...               ...
# 29927                    0  ...            208365             88004
# 29928                   -1  ...              3502              8979
# 29929                    2  ...              2758             20878
# 29930                    0  ...             76304             52774
# 29931                    0  ...             49764             36535
#
#        extrato_mai_2005  extrato_abr_2005  valor_pag_set_2005  \
# 0                     0                 0                   0
# 1                  3455              3261                   0
# 2                 14948             15549                1518
# 3                 28959             29547                2000
# 4                 19146             19131                2000
# ...                 ...               ...                 ...
# 29927             31237             15980                8500
# 29928              5190                 0                1837
# 29929             20582             19357                   0
# 29930             11855             48944               85900
# 29931             32428             15313                2078
#
#        valor_pag_ago_2005  valor_pag_jul_2005  valor_pag_jun_2005  \
# 0                     689                   0                   0
# 1                    1000                1000                1000
# 2                    1500                1000                1000
# 3                    2019                1200                1100
# 4                   36681               10000                9000
# ...                   ...                 ...                 ...
# 29927               20000                5003                3047
# 29928                3526                8998                 129
# 29929                   0               22000                4200
# 29930                3409                1178                1926
# 29931                1800                1430                1000
#
#        valor_pag_mai_2005  valor_pag_abr_2005
# 0                       0                   0
# 1                       0                2000
# 2                    1000                5000
# 3                    1069                1000
# 4                     689                 679
# ...                   ...                 ...
# 29927                5000                1000
# 29928                   0                   0
# 29929                2000                3100
# 29930               52964                1804
# 29931                1000                1000
#
# [29932 rows x 25 columns]

# %%
# Histograma

plt.figure(figsize=(10,10))

sns.histplot(credit, x="idade", hue="sexo", palette="light:m_r");

plt.legend(labels=["Masculino","Feminino"]);

# 1=Masculino, 2=Feminino
